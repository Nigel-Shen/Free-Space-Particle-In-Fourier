# %%
from rich import print
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import pandas as pd
import seaborn as sns
DT=1
sns.set()
plt.rcParams["font.family"] = "Times"
plt.rcParams['mathtext.fontset'] = 'custom'
plt.rcParams['mathtext.rm'] = 'Times'
plt.rcParams['mathtext.it'] = 'Times:italic'
plt.rcParams['mathtext.bf'] = 'Times:bold'
import cylinder
# Out:
# /Users/nigelshen/Desktop/NYU/PIC/PIC_v2.0/cylinder.py:34: RuntimeWarning: invalid value encountered in divide
#   green = (1-sp.jv(0, LT*s)) / (s**2) - (LT*np.log(LT)*sp.jv(1, LT*s)) / s ## Green function in spectral space
# 0
# 2500
# 5000
# 7500
# /Users/nigelshen/Desktop/NYU/PIC/PIC_v2.0/cylinder.py:143: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   energies = energies.append({"DT": DT, "Energy": np.max(np.abs((Etotals-Etotals[0])/Etotals[0])), "Type": "Numerical Error"}, ignore_index=True)
# /Users/nigelshen/Desktop/NYU/PIC/PIC_v2.0/cylinder.py:144: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   energies = energies.append({"DT": DT, "Energy": DT ** 2, "Type": "2nd Order Reference"}, ignore_index=True)
# MovieWriter Pillow unavailable; using Pillow instead.

# %%
plt.rcParams["font.family"] = "Times"

fig, axes = plt.subplots(2, 2, dpi=300, figsize=(15,12))

cmap = sns.color_palette("light:b", as_cmap=True)
for i in range(0, len(cyclotron.rho_abs)):
    sns.heatmap(data=cyclotron.rho_abs[i], ax=axes.flat[i], cmap=cmap)
    axes.flat[i].set_title('T = '+ str(i*2500*0.002))
    axes.flat[i].axis('equal')
plt.show()

#plt.rcParams["font.family"] = "Times"
#sns.set(font_scale=1.4)  # Adjust the font size as needed
# Out:
# 0.06249971893169995

# %%
sns.set(rc={"font.family": "Helvetica"}, font_scale=1.4)
# Define the perceptually uniform colormap
colormap = sns.cubehelix_palette(start=.5, rot=-.5, as_cmap=True, reverse=True)  # You can also try 'plasma' or other colormaps from Seaborn

# import matplotlib.patches as patches
# Your existing code
plt.rcParams["font.family"] = "Times"
fig1, axes1 = plt.subplots(2, 2, dpi=300, figsize=(10, 8))
for i in range(0, len(cylinder.rhos)):
    sns.heatmap(data=cylinder.rhos[i], ax=axes1.flat[i], xticklabels=False, yticklabels=False, cmap=colormap)
    axes1.flat[i].scatter(cylinder.XB[0,:] * cylinder.NG + cylinder.NG//2 , cylinder.XB[1,:] * cylinder.NG + cylinder.NG//2, edgecolor='#DDDDDD', linewidth=0.5, s=10, c=sns.color_palette()[9])
    axes1.flat[i].set_title('T = ' + str(i * 2500 * 0.002))
    axes1.flat[i].axis('equal')
    #circle = patches.Circle((64, 64), 64, linewidth=2, edgecolor='gray', facecolor='none')
    #axes1.flat[i].add_patch(circle)
print(np.sum(cylinder.rhos[0])/128**2)
#plt.tight_layout()  # To improve the layout
plt.show()
# Out:
# /var/folders/86/0dvym1n11pq3yfz2v0bcnv2h0000gn/T/ipykernel_8865/3976127674.py:11: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axes1.flat[i].scatter(cylinder.XB[0,:] * cylinder.NG + cylinder.NG//2 , cylinder.XB[1,:] * cylinder.NG + cylinder.NG//2, edgecolor='#DDDDDD', linewidth=0.5, s=10, c=sns.color_palette()[9])
# 0.9999998992560944

# %%
plt.rcParams["font.family"] = "Times"
energies = cylinder.energies.pivot("Time", "DT", "Energy")
#print(energies)
fig1, axes1 = plt.subplots(1,1, dpi=300, figsize=(9,6))
sns.lineplot(data=energies, ax=axes1, linewidth=1.5)
plt.title("Total energy over time for different " + r"$\Delta t$")
plt.show()
# Out:
# /var/folders/86/0dvym1n11pq3yfz2v0bcnv2h0000gn/T/ipykernel_5232/1993443545.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   energies = cyclotron.energies.pivot("Time", "DT", "Energy")

# %%
# Set the font family and font size for the plot using sns.set()
sns.set(rc={'font.family': 'Times','xtick.major.size': 6, 'ytick.major.size': 6,
            'xtick.minor.size': 6, 'ytick.minor.size': 6})

fig1, axes1 = plt.subplots(1,1, dpi=300, figsize=(9, 6))
energies = cylinder.energies.pivot("DT", "Type", "Energy")
sns.lineplot(data=energies, ax=axes1, markers=True, linewidth=2, markersize=10)
plt.yscale('log')
plt.xscale('log')
plt.grid(which='both', axis='both', linestyle='-', linewidth=1, color='white')
plt.minorticks_on()
plt.grid(which='minor', axis='both', linestyle=':', linewidth=1, color='white')
plt.xlabel(r"$\Delta t$")
plt.title("Global energy error with respect to " + r"$\Delta t$" + " for Dirichlet BC")
plt.show()
# Out:
# /var/folders/86/0dvym1n11pq3yfz2v0bcnv2h0000gn/T/ipykernel_8773/1305272064.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   energies = cylinder.energies.pivot("DT", "Type", "Energy")

# %%
import pretty_errors

# %%
import cyclotron_pic
plt.rcParams["font.family"] = "Times"
# cyclotron.energies = pd.concat([cyclotron.energies, cyclotron_pic.energies])
# energies = cyclotron.energies.pivot("Time", "Method", "Energy")
cyclotron.energies['Time'] = cyclotron.energies['Time'].astype(float)
fig1, axes1 = plt.subplots(1,1, dpi=300, figsize=(12, 7.5))
sns.lineplot(data=cyclotron.energies, x="Time", y="Energy", hue="Method", ax=axes1, linewidth=2)
plt.title("Normalized Energy for FSPIC and FSPIF, with " + r"$\Delta t = 0.0005$")
plt.show()
# Out:
# /Users/nigelshen/anaconda3/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /Users/nigelshen/anaconda3/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /Users/nigelshen/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:5404: ComplexWarning: Casting complex values to real discards the imaginary part
#   pts[0] = start
# /Users/nigelshen/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:5405: ComplexWarning: Casting complex values to real discards the imaginary part
#   pts[N + 1] = end
# /Users/nigelshen/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:5408: ComplexWarning: Casting complex values to real discards the imaginary part
#   pts[1:N+1, 1] = dep1slice
# ...

# %%
sns.color_palette()
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]
